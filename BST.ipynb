# %% [markdown]
# ## Insertion and Inorder Traveral in BST

# %%
## class of nodes in BST

class Node:
    def __init__(self,data):
        self.left = None
        self.right = None
        self.data = data 

## Insertion in BST
def insertBST(root,key):
    if root is None:
        return Node(key)
    else:
        if root.data == key:
            return root
        elif root.data < key:
            root.right = insertBST(root.right,key)
        else:
            root.left =insertBST(root.left,key)
    return root

## Inorder Traversal in BST
def inOrder(root):
    if root:
        inOrder(root.left)
        print(str(root.data)+" ", end =' ')
        inOrder(root.right)



root = Node(100)
root = insertBST(root,80)
root = insertBST(root,110)
root = insertBST(root,50)
root = insertBST(root,90)


print("Inorder Traversal:")
inOrder(root)
# Out:
# Inorder Traversal:
# 50  80  90  100  110

# %% [markdown]
# ## Minimum Value in BST

# %%
## class of nodes in BST

class Node:
    def __init__(self,data):
        self.left = None
        self.right = None
        self.data = data 

## Insertion in BST
def insertBST(root,key):
    if root is None:
        return Node(key)
    else:
        if root.data == key:
            return root
        elif root.data < key:
            root.right = insertBST(root.right,key)
        else:
            root.left =insertBST(root.left,key)
    return root

def searchInBST(root,key):
    if root.data ==


def minValBST(root):
    temp = root
    while temp.left:
        temp = temp.left
    return temp.data

def maxValBST(root):
    temp = root
    while temp.right:
        temp = temp.right
    return temp.data

root = Node(100)
root = insertBST(root,80)
root = insertBST(root,110)
root = insertBST(root,50)
root = insertBST(root,90)
root = insertBST(root,10)
result = minValBST(root)
result2= maxValBST(root)

print("Minimum val in BST is: ",result)
print("Maximum val in BST is: ",result2)
# Out:
# Minimum val in BST is:  10
# Maximum val in BST is:  110

# %% [markdown]
# ## Searching in BST

# %%
## class of nodes in BST
# TC = O(h) → which is O(log n) for a balanced BST and O(n) for an unbalanced BST


class Node:
    def __init__(self,data):
        self.left = None
        self.right = None
        self.data = data 

## Insertion in BST
def insertBST(root,key):
    if root is None:
        return Node(key)
    else:
        if root.data == key:
            return root
        elif root.data < key:
            root.right = insertBST(root.right,key)
        else:
            root.left =insertBST(root.left,key)
    return root

def searchInBST(root,key):
    if root is None:
        return False 
        
    if root.data == key:
        return True
    else:
        if root.data > key:
            return searchInBST(root.left,key)
        else:
            return searchInBST(root.right,key)



root = Node(100)
root = insertBST(root,80)
root = insertBST(root,110)
root = insertBST(root,50)
root = insertBST(root,90)
root = insertBST(root,10)


result = searchInBST(root,50)
print("Result:", result)
# Out:
# Result: True

# %% [markdown]
# ## Find Unique possible BST's

# %%
# Catalan numbers
# if c0=c1 = 1 

# cn = c0cn-1 + c1n-2 + _________+cn-1+c0

# c2 = c0c1 + c1c0 = 1 + 1 = 2
# c3 = c0c2 + c1c1 + c2c0 = 1*2 + 1 + 2 = 5

# %%
## Method Definition 
def findUniqueBST(n):
    n1,n2,sum_val = 0,0,0
    if n == 0  or n ==1:
        return 1
    ## catalan number series
    for i in range(1,n+1):
        n1 = findUniqueBST(i-1)
        n2 = findUniqueBST(n-i)
        sum_val = sum_val+ n1*n2
    return sum_val

# Driver code 
n = 8 # no. of nodes
result = findUniqueBST(n)
print("Number of unique possible BST:", result)
# Out:
# Number of unique possible BST: 1430

# %% [markdown]
# ## Deletion  in BST

# %%
## class of nodes in BST

class Node:
    def __init__(self,data):
        self.left = None
        self.right = None
        self.data = data 

## Insertion in BST
def insertBST(root,key):
    if root is None:
        return Node(key)
    else:
        if root.data == key:
            return root
        elif root.data < key:
            root.right = insertBST(root.right,key)
        else:
            root.left =insertBST(root.left,key)
    return root



def minValBST(root):
    temp = root
    while temp.left:
        temp = temp.left
    return temp.data

##deletion of node in BST
def deleteNode(root,key):
    if root is None:
        return root
    ## Saerching the node in BST
    if key < root.data:
        root.left = deleteNode(root.left,key)
    elif key > root.data:
        root.right = deleteNode(root.right,key)
    else:
        # case 1 and case 2 
        if root.left is None:
            temp = root.right
            root = None
            return temp
        elif root.right is None:
            temp = root.left
            root = None 
            return temp
        # case 3 - two child 
        temp =minValBST(root.right)
        print()
        print("min val: ", temp)
        root.key = temp

        ## delete the inorder successor
        root.right = deleteNode(root.right,temp)
    return root
            
            
        

root = Node(100)
root = insertBST(root,80)
root = insertBST(root,110)
root = insertBST(root,50)
root = insertBST(root,20)
root = insertBST(root,90)
result = minValBST(root)

## no child 
deleteNode(root,90)
print()
print("Inorder Traversal of the modified tree")
inOrder(root)

## single child 
deleteNode(root,50)
print()
print("Inorder Traversal of the modified tree")
inOrder(root)

## Two child 
deleteNode(root,100)
print()
print("Inorder Traversal of the modified tree")
inOrder(root)

print("\nMinimum val in BST is: ",result)


deleteNode(root,20)
print()
print("Inorder Traversal of the modified tree")
inOrder(root)
# Out:
# Inorder Traversal of the modified tree
# 20  50  80  100  110
# Inorder Traversal of the modified tree
# 20  80  100  110
# min val:  110
#
# Inorder Traversal of the modified tree
# 20  80  100
# Minimum val in BST is:  20
#
# Inorder Traversal of the modified tree
# 80  100
